# %%
from benchmarking import Timer, timer
import xarray as xr
import iris
import timeit
# Out:
# /home/olnavy/anaconda3/envs/Olnavy/lib/python3.7/site-packages/xarray/core/merge.py:17: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)

# %% [markdown]
# ## Opening amd storing dataset

# %% [markdown]
# ### Monthly surface atmosphere

# %%
# 1 month
# %timeit iris.load('/Documents/Documents/Cours/PHD/data/pd/xosfaa#pd000003500ja+.nc')
# %timeit xr.open_dataset('/Documents/Documents/Cours/PHD/data/pd/xosfaa#pd000003500ja+.nc')
# %timeit xr.open_mfdataset('/Documents/Documents/Cours/PHD/data/pd/xosfaa#pd000003500ja+.nc')
# %timeit 

# 1 year

# 2 years
# Out:
# 27.1 ms ± 431 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# /home/olnavy/anaconda3/envs/Olnavy/lib/python3.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:2190: UserWarning: Ignoring netCDF variable 'level6' invalid units 'level'
#   warnings.warn(msg)
# /home/olnavy/anaconda3/envs/Olnavy/lib/python3.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:2190: UserWarning: Ignoring netCDF variable 'surface' invalid units 'level'
#   warnings.warn(msg)
# /home/olnavy/anaconda3/envs/Olnavy/lib/python3.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:2190: UserWarning: Ignoring netCDF variable 'surface' invalid units 'level'
#   warnings.warn(msg)
# /home/olnavy/anaconda3/envs/Olnavy/lib/python3.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:2190: UserWarning: Ignoring netCDF variable 'toa' invalid units 'level'
#   warnings.warn(msg)
# ...
